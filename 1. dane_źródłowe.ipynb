# %% [markdown]
# # Import niezbędnych bibliotek

# %%
import pandas as pd
import yfinance as yf
from yahooquery import Ticker
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import norm
import statsmodels.api as sm

% matplotlib inline

sns.set_style('darkgrid')

# %% [markdown]
# # Dane udostępniane przez bibliotekę portal Yahoo Finance na przykładzie firmy Apple

# %%
stocks = ['AAPL', 'JPM', 'PG', 'FDX', 'MMM', '^GSPC']

stocks_info = {}
key_stats_info = {}
for stock in stocks:
    stocks_info[stock] = Ticker(stock).summary_detail[stock]

info_df = pd.DataFrame(stocks_info)
key_stats_df = pd.DataFrame(key_stats_info)
info_df
# Out:
#                                              AAPL                  JPM  \
# maxAge                                          1                    1
# priceHint                                       2                    2
# previousClose                              172.07               134.32
# open                                       171.71                135.9
# dayLow                                    170.422               135.47
# dayHigh                                    172.15               136.88
# regularMarketPreviousClose                 172.07               134.32
# regularMarketOpen                          171.71                135.9
# regularMarketDayLow                       170.422               135.47
# regularMarketDayHigh                       172.15               136.88
# dividendRate                                 0.96                  4.0
# dividendYield                              0.0056               0.0296
# exDividendDate                2023-05-12 02:00:00  2023-04-05 02:00:00
# payoutRatio                                0.1559                0.295
# fiveYearAvgDividendYield                     0.92                 2.78
# beta                                     1.296622             1.082688
# trailingPE                              28.967796             9.999631
# forwardPE                               26.133028             9.713109
# volume                                   12602976              2120418
# regularMarketVolume                      12602976              2120418
# averageVolume                            58153583             14843296
# averageVolume10days                      58905230              9540150
# averageDailyVolume10Day                  58905230              9540150
# bid                                        170.76                135.8
# ask                                        170.75               135.82
# bidSize                                      1100                  900
# askSize                                       800                 1000
# marketCap                           2688192348160         396247891968
# fiftyTwoWeekLow                            124.17               101.28
# fiftyTwoWeekHigh                           176.15               144.34
# priceToSalesTrailing12Months             6.980595             3.068692
# fiftyDayAverage                          163.1642             133.3784
# twoHundredDayAverage                    151.96545             128.7315
# trailingAnnualDividendRate                   0.92                  4.0
# trailingAnnualDividendYield              0.005347              0.02978
# currency                                      USD                  USD
# fromCurrency                                 None                 None
# toCurrency                                   None                 None
# lastMarket                                   None                 None
# coinMarketCapLink                            None                 None
# algorithm                                    None                 None
# tradeable                                   False                False
#
#                                                PG                  FDX  \
# maxAge                                          1                    1
# priceHint                                       2                    2
# previousClose                              155.74               221.27
# open                                       156.26               221.48
# dayLow                                     154.85               221.48
# dayHigh                                    156.56               222.74
# regularMarketPreviousClose                 155.74               221.27
# regularMarketOpen                          156.26               221.48
# regularMarketDayLow                        154.85               221.48
# regularMarketDayHigh                       156.56               222.74
# dividendRate                                 3.76                 5.04
# dividendYield                              0.0241               0.0227
# exDividendDate                2023-04-20 02:00:00  2023-06-09 02:00:00
# payoutRatio                                0.6353               0.2969
# fiveYearAvgDividendYield                     2.58                 1.44
# beta                                     0.394792             1.339901
# trailingPE                              26.930435             19.24632
# forwardPE                                24.27116            12.140634
# volume                                     485188               135291
# regularMarketVolume                        485188               135291
# averageVolume                             6081870              2058416
# averageVolume10days                       4858740              1329880
# averageDailyVolume10Day                   4858740              1329880
# bid                                        155.08               222.11
# ask                                        155.12               222.18
# bidSize                                      1200                 1000
# askSize                                       800                  800
# marketCap                            364976832512          55874293760
# fiftyTwoWeekLow                            122.18               141.92
# fiftyTwoWeekHigh                           158.11               248.76
# priceToSalesTrailing12Months             4.507668              0.60327
# fiftyDayAverage                          149.5738             222.3652
# twoHundredDayAverage                     143.3145            195.65575
# trailingAnnualDividendRate                  3.653                  4.6
# trailingAnnualDividendYield              0.023456             0.020789
# currency                                      USD                  USD
# fromCurrency                                 None                 None
# toCurrency                                   None                 None
# lastMarket                                   None                 None
# coinMarketCapLink                            None                 None
# algorithm                                    None                 None
# tradeable                                   False                False
#
#                                               MMM       ^GSPC
# maxAge                                          1           1
# priceHint                                       2           2
# previousClose                               98.01      4109.9
# open                                        98.42     4122.85
# dayLow                                       98.0     4113.62
# dayHigh                                    98.586     4130.12
# regularMarketPreviousClose                  98.01      4109.9
# regularMarketOpen                           98.42     4122.85
# regularMarketDayLow                          98.0     4113.62
# regularMarketDayHigh                       98.586     4130.12
# dividendRate                                  6.0         NaN
# dividendYield                              0.0597         NaN
# exDividendDate                2023-05-18 02:00:00         NaN
# payoutRatio                                0.6167         NaN
# fiveYearAvgDividendYield                     3.61         NaN
# beta                                     0.948979         NaN
# trailingPE                              10.139462         NaN
# forwardPE                               10.223958         NaN
# volume                                     527353   398177334
# regularMarketVolume                        527353   398177334
# averageVolume                             3388398  4267338000
# averageVolume10days                       2630130  3936482000
# averageDailyVolume10Day                   2630130  3936482000
# bid                                         98.23     4118.27
# ask                                         98.24     4120.19
# bidSize                                       800           0
# askSize                                       800           0
# marketCap                             54146609152         NaN
# fiftyTwoWeekLow                              98.0     3491.58
# fiftyTwoWeekHigh                            152.3     4325.28
# priceToSalesTrailing12Months             1.619653         NaN
# fiftyDayAverage                          103.4734   4060.5884
# twoHundredDayAverage                    118.14095    3974.828
# trailingAnnualDividendRate                   5.97         NaN
# trailingAnnualDividendYield              0.060912         NaN
# currency                                      USD         USD
# fromCurrency                                 None        None
# toCurrency                                   None        None
# lastMarket                                   None        None
# coinMarketCapLink                            None        None
# algorithm                                    None        None
# tradeable                                   False       False

# %%
Ticker('AAPL').all_modules # JSON zawierający wszystkie dostępne moduły
# Out:
# {'AAPL': {'assetProfile': {'address1': 'One Apple Park Way',
#    'city': 'Cupertino',
#    'state': 'CA',
#    'zip': '95014',
#    'country': 'United States',
#    'phone': '408 996 1010',
#    'website': 'https://www.apple.com',
#    'industry': 'Consumer Electronics',
#    'industryDisp': 'Consumer Electronics',
#    'sector': 'Technology',
#    'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In addition, the company offers various services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was incorporated in 1977 and is headquartered in Cupertino, California.',
#    'fullTimeEmployees': 164000,
#    'companyOfficers': [{'maxAge': 1,
#      'name': 'Mr. Timothy D. Cook',
#      'age': 61,
#      'title': 'CEO & Director',
#      'yearBorn': 1961,
#      'fiscalYear': 2022,
#      'totalPay': 16425933,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Luca  Maestri',
#      'age': 59,
#      'title': 'CFO & Sr. VP',
#      'yearBorn': 1963,
#      'fiscalYear': 2022,
#      'totalPay': 5019783,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Jeffrey E. Williams',
#      'age': 58,
#      'title': 'Chief Operating Officer',
#      'yearBorn': 1964,
#      'fiscalYear': 2022,
#      'totalPay': 5018337,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Ms. Katherine L. Adams',
#      'age': 58,
#      'title': 'Sr. VP, Gen. Counsel & Sec.',
#      'yearBorn': 1964,
#      'fiscalYear': 2022,
#      'totalPay': 5015208,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': "Ms. Deirdre  O'Brien",
#      'age': 55,
#      'title': 'Sr. VP of Retail',
#      'yearBorn': 1967,
#      'fiscalYear': 2022,
#      'totalPay': 5019783,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Chris  Kondo',
#      'title': 'Sr. Director of Corp. Accounting',
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. James  Wilson',
#      'title': 'Chief Technology Officer',
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Ms. Mary  Demby',
#      'title': 'Chief Information Officer',
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Ms. Nancy  Paxton',
#      'title': 'Sr. Director of Investor Relations & Treasury',
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Greg  Joswiak',
#      'title': 'Sr. VP of Worldwide Marketing',
#      'exercisedValue': 0,
#      'unexercisedValue': 0}],
#    'auditRisk': 4,
#    'boardRisk': 1,
#    'compensationRisk': 5,
#    'shareHolderRightsRisk': 1,
#    'overallRisk': 1,
#    'governanceEpochDate': '2023-05-01 02:00:00',
#    'compensationAsOfEpochDate': '2022-12-31 01:00:00',
#    'maxAge': 86400},
#   'recommendationTrend': {'trend': [{'period': '0m',
#      'strongBuy': 11,
#      'buy': 21,
#      'hold': 6,
#      'sell': 0,
#      'strongSell': 0},
#     {'period': '-1m',
#      'strongBuy': 9,
#      'buy': 24,
#      'hold': 7,
#      'sell': 1,
#      'strongSell': 0},
#     {'period': '-2m',
#      'strongBuy': 9,
#      'buy': 24,
#      'hold': 7,
#      'sell': 1,
#      'strongSell': 0},
#     {'period': '-3m',
#      'strongBuy': 13,
#      'buy': 20,
#      'hold': 8,
#      'sell': 0,
#      'strongSell': 0}],
#    'maxAge': 86400},
#   'cashflowStatementHistory': {'cashflowStatements': [{'maxAge': 1,
#      'endDate': '2022-09-24',
#      'netIncome': 99803000000,
#      'depreciation': 11104000000,
#      'changeToNetincome': 10044000000,
#      'changeToAccountReceivables': -1823000000,
#      'changeToLiabilities': 9926000000,
#      'changeToInventory': 1484000000,
#      'changeToOperatingActivities': -8387000000,
#      'totalCashFromOperatingActivities': 122151000000,
#      'capitalExpenditures': -10708000000,
#      'investments': -9560000000,
#      'otherCashflowsFromInvestingActivities': -1780000000,
#      'totalCashflowsFromInvestingActivities': -22354000000,
#      'dividendsPaid': -14841000000,
#      'netBorrowings': -123000000,
#      'otherCashflowsFromFinancingActivities': -160000000,
#      'totalCashFromFinancingActivities': -110749000000,
#      'changeInCash': -10952000000,
#      'repurchaseOfStock': -95625000000},
#     {'maxAge': 1,
#      'endDate': '2021-09-25',
#      'netIncome': 94680000000,
#      'depreciation': 11284000000,
#      'changeToNetincome': 2985000000,
#      'changeToAccountReceivables': -10125000000,
#      'changeToLiabilities': 14002000000,
#      'changeToInventory': -2642000000,
#      'changeToOperatingActivities': -6146000000,
#      'totalCashFromOperatingActivities': 104038000000,
#      'capitalExpenditures': -11085000000,
#      'investments': -3075000000,
#      'otherCashflowsFromInvestingActivities': -352000000,
#      'totalCashflowsFromInvestingActivities': -14545000000,
#      'dividendsPaid': -14467000000,
#      'netBorrowings': 12665000000,
#      'otherCashflowsFromFinancingActivities': 976000000,
#      'totalCashFromFinancingActivities': -93353000000,
#      'changeInCash': -3860000000,
#      'repurchaseOfStock': -92527000000},
#     {'maxAge': 1,
#      'endDate': '2020-09-26',
#      'netIncome': 57411000000,
#      'depreciation': 11056000000,
#      'changeToNetincome': 6517000000,
#      'changeToAccountReceivables': 6917000000,
#      'changeToLiabilities': -1981000000,
#      'changeToInventory': -127000000,
#      'changeToOperatingActivities': 881000000,
#      'totalCashFromOperatingActivities': 80674000000,
#      'capitalExpenditures': -7309000000,
#      'investments': 5453000000,
#      'otherCashflowsFromInvestingActivities': -909000000,
#      'totalCashflowsFromInvestingActivities': -4289000000,
#      'dividendsPaid': -14081000000,
#      'netBorrowings': 2499000000,
#      'otherCashflowsFromFinancingActivities': 754000000,
#      'totalCashFromFinancingActivities': -86820000000,
#      'changeInCash': -10435000000,
#      'repurchaseOfStock': -75992000000},
#     {'maxAge': 1,
#      'endDate': '2019-09-28',
#      'netIncome': 55256000000,
#      'depreciation': 12547000000,
#      'changeToNetincome': 5076000000,
#      'changeToAccountReceivables': 245000000,
#      'changeToLiabilities': -2548000000,
#      'changeToInventory': -289000000,
#      'changeToOperatingActivities': -896000000,
#      'totalCashFromOperatingActivities': 69391000000,
#      'capitalExpenditures': -10495000000,
#      'investments': 58093000000,
#      'otherCashflowsFromInvestingActivities': -1078000000,
#      'totalCashflowsFromInvestingActivities': 45896000000,
#      'dividendsPaid': -14119000000,
#      'netBorrowings': -7819000000,
#      'otherCashflowsFromFinancingActivities': -105000000,
#      'totalCashFromFinancingActivities': -90976000000,
#      'changeInCash': 24311000000,
#      'repurchaseOfStock': -69714000000,
#      'issuanceOfStock': 781000000}],
#    'maxAge': 86400},
#   'indexTrend': {'maxAge': 1,
#    'symbol': 'SP5',
#    'peRatio': 15.6832,
#    'pegRatio': 1.72109,
#    'estimates': [{'period': '0q', 'growth': -0.009},
#     {'period': '+1q', 'growth': 0.084},
#     {'period': '0y', 'growth': 0.006},
#     {'period': '+1y', 'growth': 0.107},
#     {'period': '+5y', 'growth': 0.0770297},
#     {'period': '-5y'}]},
#   'defaultKeyStatistics': {'maxAge': 1,
#    'priceHint': 2,
#    'enterpriseValue': 2760180760576,
#    'forwardPE': 26.133028,
#    'profitMargins': 0.24493,
#    'floatShares': 15710299419,
#    'sharesOutstanding': 15728700416,
#    'sharesShort': 124657645,
#    'sharesShortPriorMonth': 111566048,
#    'sharesShortPreviousMonthDate': '2023-03-31 02:00:00',
#    'dateShortInterest': '2023-04-28 02:00:00',
#    'sharesPercentSharesOut': 0.007900001,
#    'heldPercentInsiders': 0.00071000005,
#    'heldPercentInstitutions': 0.61232,
#    'shortRatio': 2.42,
#    'shortPercentOfFloat': 0.007900001,
#    'beta': 1.296622,
#    'impliedSharesOutstanding': 15728700416,
#    'category': None,
#    'bookValue': 3.953,
#    'priceToBook': 43.23552,
#    'fundFamily': None,
#    'legalType': None,
#    'lastFiscalYearEnd': '2022-09-24 02:00:00',
#    'nextFiscalYearEnd': '2023-09-24 02:00:00',
#    'mostRecentQuarter': '2023-04-01 02:00:00',
#    'earningsQuarterlyGrowth': -0.034,
#    'netIncomeToCommon': 94321000448,
#    'trailingEps': 5.9,
#    'forwardEps': 6.54,
#    'pegRatio': 3.59,
#    'lastSplitFactor': '4:1',
#    'lastSplitDate': '2020-08-31 02:00:00',
#    'enterpriseToRevenue': 7.168,
#    'enterpriseToEbitda': 22.298,
#    '52WeekChange': 0.22191453,
#    'SandP52WeekChange': 0.047460556,
#    'lastDividendValue': 0.24,
#    'lastDividendDate': 1683849600},
#   'industryTrend': {'maxAge': 1, 'symbol': None, 'estimates': []},
#   'quoteType': {'exchange': 'NMS',
#    'quoteType': 'EQUITY',
#    'symbol': 'AAPL',
#    'underlyingSymbol': 'AAPL',
#    'shortName': 'Apple Inc.',
#    'longName': 'Apple Inc.',
#    'firstTradeDateEpochUtc': '1980-12-12 15:30:00',
#    'timeZoneFullName': 'America/New_York',
#    'timeZoneShortName': 'EDT',
#    'uuid': '8b10e4ae-9eeb-3684-921a-9ab27e4d87aa',
#    'messageBoardId': 'finmb_24937',
#    'gmtOffSetMilliseconds': -14400000,
#    'maxAge': 1},
#   'incomeStatementHistory': {'incomeStatementHistory': [{'maxAge': 1,
#      'endDate': '2022-09-24',
#      'totalRevenue': 394328000000,
#      'costOfRevenue': 223546000000,
#      'grossProfit': 170782000000,
#      'researchDevelopment': 26251000000,
#      'sellingGeneralAdministrative': 25094000000,
#      'nonRecurring': {},
#      'otherOperatingExpenses': {},
#      'totalOperatingExpenses': 274891000000,
#      'operatingIncome': 119437000000,
#      'totalOtherIncomeExpenseNet': -334000000,
#      'ebit': 119437000000,
#      'interestExpense': -2931000000,
#      'incomeBeforeTax': 119103000000,
#      'incomeTaxExpense': 19300000000,
#      'minorityInterest': {},
#      'netIncomeFromContinuingOps': 99803000000,
#      'discontinuedOperations': {},
#      'extraordinaryItems': {},
#      'effectOfAccountingCharges': {},
#      'otherItems': {},
#      'netIncome': 99803000000,
#      'netIncomeApplicableToCommonShares': 99803000000},
#     {'maxAge': 1,
#      'endDate': '2021-09-25',
#      'totalRevenue': 365817000000,
#      'costOfRevenue': 212981000000,
#      'grossProfit': 152836000000,
#      'researchDevelopment': 21914000000,
#      'sellingGeneralAdministrative': 21973000000,
#      'nonRecurring': {},
#      'otherOperatingExpenses': {},
#      'totalOperatingExpenses': 256868000000,
#      'operatingIncome': 108949000000,
#      'totalOtherIncomeExpenseNet': 258000000,
#      'ebit': 108949000000,
#      'interestExpense': -2645000000,
#      'incomeBeforeTax': 109207000000,
#      'incomeTaxExpense': 14527000000,
#      'minorityInterest': {},
#      'netIncomeFromContinuingOps': 94680000000,
#      'discontinuedOperations': {},
#      'extraordinaryItems': {},
#      'effectOfAccountingCharges': {},
#      'otherItems': {},
#      'netIncome': 94680000000,
#      'netIncomeApplicableToCommonShares': 94680000000},
#     {'maxAge': 1,
#      'endDate': '2020-09-26',
#      'totalRevenue': 274515000000,
#      'costOfRevenue': 169559000000,
#      'grossProfit': 104956000000,
#      'researchDevelopment': 18752000000,
#      'sellingGeneralAdministrative': 19916000000,
#      'nonRecurring': {},
#      'otherOperatingExpenses': {},
#      'totalOperatingExpenses': 208227000000,
#      'operatingIncome': 66288000000,
#      'totalOtherIncomeExpenseNet': 803000000,
#      'ebit': 66288000000,
#      'interestExpense': -2873000000,
#      'incomeBeforeTax': 67091000000,
#      'incomeTaxExpense': 9680000000,
#      'minorityInterest': {},
#      'netIncomeFromContinuingOps': 57411000000,
#      'discontinuedOperations': {},
#      'extraordinaryItems': {},
#      'effectOfAccountingCharges': {},
#      'otherItems': {},
#      'netIncome': 57411000000,
#      'netIncomeApplicableToCommonShares': 57411000000},
#     {'maxAge': 1,
#      'endDate': '2019-09-28',
#      'totalRevenue': 260174000000,
#      'costOfRevenue': 161782000000,
#      'grossProfit': 98392000000,
#      'researchDevelopment': 16217000000,
#      'sellingGeneralAdministrative': 18245000000,
#      'nonRecurring': {},
#      'otherOperatingExpenses': {},
#      'totalOperatingExpenses': 196244000000,
#      'operatingIncome': 63930000000,
#      'totalOtherIncomeExpenseNet': 1807000000,
#      'ebit': 63930000000,
#      'interestExpense': -3576000000,
#      'incomeBeforeTax': 65737000000,
#      'incomeTaxExpense': 10481000000,
#      'minorityInterest': {},
#      'netIncomeFromContinuingOps': 55256000000,
#      'discontinuedOperations': {},
#      'extraordinaryItems': {},
#      'effectOfAccountingCharges': {},
#      'otherItems': {},
#      'netIncome': 55256000000,
#      'netIncomeApplicableToCommonShares': 55256000000}],
#    'maxAge': 86400},
#   'fundOwnership': {'maxAge': 1,
#    'ownershipList': [{'maxAge': 1,
#      'reportDate': '2022-12-31',
#      'organization': 'Vanguard Total Stock Market Index Fund',
#      'pctHeld': 0.029000001,
#      'position': 459387185,
#      'value': 78513865470,
#      'pctChange': 0.0094},
#     {'maxAge': 1,
#      'reportDate': '2022-12-31',
#      'organization': 'Vanguard 500 Index Fund',
#      'pctHeld': 0.0218,
#      'position': 345686331,
#      'value': 59081252097,
#      'pctChange': 0.0094},
#     {'maxAge': 1,
#      'reportDate': '2023-02-28',
#      'organization': 'Fidelity 500 Index Fund',
#      'pctHeld': 0.0104,
#      'position': 163930044,
#      'value': 28017284420,
#      'pctChange': 0.0018000001},
#     {'maxAge': 1,
#      'reportDate': '2023-03-31',
#      'organization': 'SPDR S&P 500 ETF Trust',
#      'pctHeld': 0.010199999,
#      'position': 161020780,
#      'value': 27520062099,
#      'pctChange': -0.003},
#     {'maxAge': 1,
#      'reportDate': '2023-02-28',
#      'organization': 'iShares Core S&P 500 ETF',
#      'pctHeld': 0.0084,
#      'position': 133463881,
#      'value': 22810312390,
#      'pctChange': -0.0068},
#     {'maxAge': 1,
#      'reportDate': '2023-03-31',
#      'organization': 'Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF',
#      'pctHeld': 0.0082,
#      'position': 128975730,
#      'value': 22043242486,
#      'pctChange': 21.5022},
#     {'maxAge': 1,
#      'reportDate': '2022-12-31',
#      'organization': 'Vanguard Growth Index Fund',
#      'pctHeld': 0.0081,
#      'position': 127560098,
#      'value': 21801296816,
#      'pctChange': 0.014400001},
#     {'maxAge': 1,
#      'reportDate': '2022-12-31',
#      'organization': 'Vanguard Institutional Index Fund-Institutional Index Fund',
#      'pctHeld': 0.0066000004,
#      'position': 104788341,
#      'value': 17909375744,
#      'pctChange': -0.0446},
#     {'maxAge': 1,
#      'reportDate': '2022-11-30',
#      'organization': 'Vanguard Information Technology Index Fund',
#      'pctHeld': 0.0043,
#      'position': 68684835,
#      'value': 11738925401,
#      'pctChange': -0.14109999},
#     {'maxAge': 1,
#      'reportDate': '2023-02-28',
#      'organization': 'Select Sector SPDR Fund-Technology',
#      'pctHeld': 0.0039,
#      'position': 61788810,
#      'value': 10560325743,
#      'pctChange': -0.0194}]},
#   'summaryDetail': {'maxAge': 1,
#    'priceHint': 2,
#    'previousClose': 172.07,
#    'open': 171.71,
#    'dayLow': 170.422,
#    'dayHigh': 172.15,
#    'regularMarketPreviousClose': 172.07,
#    'regularMarketOpen': 171.71,
#    'regularMarketDayLow': 170.422,
#    'regularMarketDayHigh': 172.15,
#    'dividendRate': 0.96,
#    'dividendYield': 0.0056,
#    'exDividendDate': '2023-05-12 02:00:00',
#    'payoutRatio': 0.1559,
#    'fiveYearAvgDividendYield': 0.92,
#    'beta': 1.296622,
#    'trailingPE': 28.967796,
#    'forwardPE': 26.133028,
#    'volume': 12603341,
#    'regularMarketVolume': 12603341,
#    'averageVolume': 58153583,
#    'averageVolume10days': 58905230,
#    'averageDailyVolume10Day': 58905230,
#    'bid': 170.76,
#    'ask': 170.75,
#    'bidSize': 1100,
#    'askSize': 800,
#    'marketCap': 2688192348160,
#    'fiftyTwoWeekLow': 124.17,
#    'fiftyTwoWeekHigh': 176.15,
#    'priceToSalesTrailing12Months': 6.980595,
#    'fiftyDayAverage': 163.1642,
#    'twoHundredDayAverage': 151.96545,
#    'trailingAnnualDividendRate': 0.92,
#    'trailingAnnualDividendYield': 0.005346661,
#    'currency': 'USD',
#    'fromCurrency': None,
#    'toCurrency': None,
#    'lastMarket': None,
#    'coinMarketCapLink': None,
#    'algorithm': None,
#    'tradeable': False},
#   'insiderHolders': {'holders': [{'maxAge': 1,
#      'name': 'ADAMS KATHERINE L',
#      'relation': 'General Counsel',
#      'url': '',
#      'transactionDescription': 'Stock Gift',
#      'latestTransDate': '2023-05-10',
#      'positionDirect': 422313,
#      'positionDirectDate': '2023-05-10'},
#     {'maxAge': 1,
#      'name': 'COOK TIMOTHY D',
#      'relation': 'Chief Executive Officer',
#      'url': '',
#      'transactionDescription': 'Sale',
#      'latestTransDate': '2023-04-03',
#      'positionDirect': 3280050,
#      'positionDirectDate': '2023-04-03'},
#     {'maxAge': 1,
#      'name': 'JUNG ANDREA',
#      'relation': 'Director',
#      'url': '',
#      'transactionDescription': 'Conversion of Exercise of derivative security',
#      'latestTransDate': '2023-02-01',
#      'positionDirect': 141279,
#      'positionDirectDate': '2023-02-01'},
#     {'maxAge': 1,
#      'name': 'KONDO CHRISTOPHER',
#      'relation': 'Officer',
#      'url': '',
#      'transactionDescription': 'Sale',
#      'latestTransDate': '2023-05-08',
#      'positionDirect': 33946,
#      'positionDirectDate': '2023-05-08'},
#     {'maxAge': 1,
#      'name': 'LEVINSON ARTHUR D',
#      'relation': 'Director',
#      'url': '',
#      'transactionDescription': 'Stock Gift',
#      'latestTransDate': '2023-02-03',
#      'positionDirect': 4588720,
#      'positionDirectDate': '2023-02-03'},
#     {'maxAge': 1,
#      'name': 'MAESTRI LUCA',
#      'relation': 'Chief Financial Officer',
#      'url': '',
#      'transactionDescription': 'Sale',
#      'latestTransDate': '2023-04-13',
#      'positionDirect': 107661,
#      'positionDirectDate': '2023-04-13'},
#     {'maxAge': 1,
#      'name': "O'BRIEN DEIRDRE",
#      'relation': 'Officer',
#      'url': '',
#      'transactionDescription': 'Sale',
#      'latestTransDate': '2023-04-03',
#      'positionDirect': 136444,
#      'positionDirectDate': '2023-04-03'},
#     {'maxAge': 1,
#      'name': 'SUGAR RONALD D',
#      'relation': 'Director',
#      'url': '',
#      'transactionDescription': 'Conversion of Exercise of derivative security',
#      'latestTransDate': '2023-02-01',
#      'positionDirect': 105943,
#      'positionDirectDate': '2023-02-01'},
#     {'maxAge': 1,
#      'name': 'WAGNER SUSAN L',
#      'relation': 'Director',
#      'url': '',
#      'transactionDescription': 'Conversion of Exercise of derivative security',
#      'latestTransDate': '2023-02-01',
#      'positionDirect': 65523,
#      'positionDirectDate': '2023-02-01'},
#     {'maxAge': 1,
#      'name': 'WILLIAMS JEFFREY E',
#      'relation': 'Chief Operating Officer',
#      'url': '',
#      'transactionDescription': 'Sale',
#      'latestTransDate': '2023-04-04',
#      'positionDirect': 489816,
#      'positionDirectDate': '2023-04-04'}],
#    'maxAge': 1},
#   'calendarEvents': {'maxAge': 1,
#    'earnings': {'earningsDate': ['2023-07-26 22:00:S', '2023-07-31 22:00:S'],
#     'earningsAverage': 1.19,
#     'earningsLow': 1.14,
#     'earningsHigh': 1.45,
#     'revenueAverage': 81665400000,
#     'revenueLow': 79295300000,
#     'revenueHigh': 94100000000},
#    'exDividendDate': '2023-05-12 02:00:00',
#    'dividendDate': '2023-05-18 02:00:00'},
#   'upgradeDowngradeHistory': {'history': [{'epochGradeDate': '2023-05-05 16:19:12',
#      'firm': 'Raymond James',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-05-05 14:02:13',
#      'firm': 'Rosenblatt',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-05-05 13:04:39',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-05-05 12:59:59',
#      'firm': 'B of A Securities',
#      'toGrade': 'Neutral',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-05-05 11:57:45',
#      'firm': 'Needham',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-05-05 11:35:58',
#      'firm': 'Piper Sandler',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-05-05 11:33:56',
#      'firm': 'Deutsche Bank',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-05-05 11:33:06',
#      'firm': 'Atlantic Equities',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-05-05 10:42:43',
#      'firm': 'Keybanc',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-05-04 13:55:42',
#      'firm': 'Rosenblatt',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'reit'},
#     {'epochGradeDate': '2023-05-02 12:55:18',
#      'firm': 'Baird',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-05-01 13:22:44',
#      'firm': 'B of A Securities',
#      'toGrade': 'Neutral',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-04-26 12:24:05',
#      'firm': 'Deutsche Bank',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-04-26 11:58:20',
#      'firm': 'Barclays',
#      'toGrade': 'Equal-Weight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-04-19 12:00:32',
#      'firm': 'JP Morgan',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-04-17 13:48:30',
#      'firm': 'Wedbush',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'reit'},
#     {'epochGradeDate': '2023-04-13 13:28:26',
#      'firm': 'Canaccord Genuity',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-04-13 12:40:18',
#      'firm': 'Credit Suisse',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-04-05 13:23:36',
#      'firm': 'B of A Securities',
#      'toGrade': 'Neutral',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-03-30 12:45:04',
#      'firm': 'Needham',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'reit'},
#     {'epochGradeDate': '2023-03-10 14:09:45',
#      'firm': 'LightShed Partners',
#      'toGrade': 'Sell',
#      'fromGrade': 'Neutral',
#      'action': 'down'},
#     {'epochGradeDate': '2023-03-10 12:54:01',
#      'firm': 'Needham',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'reit'},
#     {'epochGradeDate': '2023-03-08 14:38:22',
#      'firm': 'Wedbush',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-03-06 11:05:09',
#      'firm': 'Goldman Sachs',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'init'},
#     {'epochGradeDate': '2023-03-02 15:17:05',
#      'firm': 'Jefferies',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'reit'},
#     {'epochGradeDate': '2023-02-06 11:31:59',
#      'firm': 'Evercore ISI Group',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'reit'},
#     {'epochGradeDate': '2023-02-03 15:31:06',
#      'firm': 'DA Davidson',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-02-03 14:30:22',
#      'firm': 'Rosenblatt',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-02-03 14:28:56',
#      'firm': 'Wedbush',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-02-03 13:42:30',
#      'firm': 'Cowen & Co.',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-02-03 13:38:06',
#      'firm': 'JP Morgan',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-02-03 13:21:03',
#      'firm': 'Raymond James',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-02-03 13:05:36',
#      'firm': 'Barclays',
#      'toGrade': 'Equal-Weight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-02-03 12:57:52',
#      'firm': 'Needham',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'reit'},
#     {'epochGradeDate': '2023-02-03 12:29:07',
#      'firm': 'Piper Sandler',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'reit'},
#     {'epochGradeDate': '2023-01-23 12:28:05',
#      'firm': 'Deutsche Bank',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-01-19 12:27:43',
#      'firm': 'JP Morgan',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-01-18 14:22:02',
#      'firm': 'Canaccord Genuity',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-01-13 15:18:55',
#      'firm': 'Rosenblatt',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-01-11 12:56:45',
#      'firm': 'Barclays',
#      'toGrade': 'Equal-Weight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-01-04 13:30:00',
#      'firm': 'Wedbush',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2023-01-03 11:26:44',
#      'firm': 'Exane BNP Paribas',
#      'toGrade': 'Neutral',
#      'fromGrade': 'Outperform',
#      'action': 'down'},
#     {'epochGradeDate': '2022-12-20 12:47:33',
#      'firm': 'JP Morgan',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-11-08 13:17:03',
#      'firm': 'UBS',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-11-08 13:14:23',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-11-07 14:08:30',
#      'firm': 'B of A Securities',
#      'toGrade': 'Neutral',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-11-07 13:39:27',
#      'firm': 'Barclays',
#      'toGrade': 'Equal-Weight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-10-28 15:19:17',
#      'firm': 'Wedbush',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-10-28 13:59:30',
#      'firm': 'Credit Suisse',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-10-28 13:31:39',
#      'firm': 'Barclays',
#      'toGrade': 'Equal-Weight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-10-28 12:39:44',
#      'firm': 'Deutsche Bank',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-10-28 12:35:31',
#      'firm': 'Citigroup',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-10-28 10:28:10',
#      'firm': 'Keybanc',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-10-17 12:26:30',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-10-13 13:57:43',
#      'firm': 'Credit Suisse',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-10-11 13:11:31',
#      'firm': 'Barclays',
#      'toGrade': 'Equal-Weight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-09-29 12:49:15',
#      'firm': 'Rosenblatt',
#      'toGrade': 'Buy',
#      'fromGrade': 'Neutral',
#      'action': 'up'},
#     {'epochGradeDate': '2022-09-29 12:27:52',
#      'firm': 'B of A Securities',
#      'toGrade': 'Neutral',
#      'fromGrade': 'Buy',
#      'action': 'down'},
#     {'epochGradeDate': '2022-09-20 14:49:31',
#      'firm': 'Evercore ISI Group',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-08-19 10:29:48',
#      'firm': 'Keybanc',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-08-17 12:22:55',
#      'firm': 'Wedbush',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-08-17 10:14:09',
#      'firm': 'Credit Suisse',
#      'toGrade': 'Outperform',
#      'fromGrade': 'Neutral',
#      'action': 'up'},
#     {'epochGradeDate': '2022-08-02 10:29:32',
#      'firm': 'Keybanc',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-07-29 13:54:26',
#      'firm': 'Rosenblatt',
#      'toGrade': 'Neutral',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-07-29 13:28:58',
#      'firm': 'Raymond James',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-07-29 13:22:13',
#      'firm': 'Barclays',
#      'toGrade': 'Equal-Weight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-07-29 12:47:12',
#      'firm': 'Citigroup',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-07-20 15:09:00',
#      'firm': 'Wells Fargo',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-07-20 14:16:27',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-07-13 13:32:45',
#      'firm': 'Barclays',
#      'toGrade': 'Equal-Weight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-07-13 12:43:08',
#      'firm': 'Citigroup',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-07-12 10:33:59',
#      'firm': 'Keybanc',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-06-28 16:15:39',
#      'firm': 'Evercore ISI Group',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-06-15 12:41:35',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-06-14 13:09:59',
#      'firm': 'Deutsche Bank',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-05-19 14:08:22',
#      'firm': 'B of A Securities',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-05-02 13:09:48',
#      'firm': 'Rosenblatt',
#      'toGrade': 'Neutral',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-04-29 14:47:34',
#      'firm': 'Credit Suisse',
#      'toGrade': 'Neutral',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-04-29 14:00:09',
#      'firm': 'Deutsche Bank',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-04-29 13:12:56',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-04-29 12:51:54',
#      'firm': 'JP Morgan',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-04-29 12:25:29',
#      'firm': 'Piper Sandler',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-04-19 14:35:08',
#      'firm': 'Rosenblatt',
#      'toGrade': 'Neutral',
#      'fromGrade': '',
#      'action': 'init'},
#     {'epochGradeDate': '2022-03-11 12:57:08',
#      'firm': 'Barclays',
#      'toGrade': 'Equal-Weight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-02-15 16:31:58',
#      'firm': 'Tigress Financial',
#      'toGrade': 'Strong Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-01-31 16:44:19',
#      'firm': 'Credit Suisse',
#      'toGrade': 'Neutral',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-01-28 16:10:56',
#      'firm': 'Oppenheimer',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-01-28 15:19:01',
#      'firm': 'New Street Research',
#      'toGrade': 'Neutral',
#      'fromGrade': 'Sell',
#      'action': 'up'},
#     {'epochGradeDate': '2022-01-28 14:01:39',
#      'firm': 'Deutsche Bank',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-01-28 13:45:37',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-01-28 13:18:25',
#      'firm': 'Raymond James',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-01-28 12:42:30',
#      'firm': 'UBS',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-01-28 12:37:56',
#      'firm': 'Barclays',
#      'toGrade': 'Equal-Weight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-01-21 14:59:41',
#      'firm': 'Wells Fargo',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2022-01-14 13:06:16',
#      'firm': 'Loop Capital',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-12-22 15:52:28',
#      'firm': 'Citigroup',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-12-14 14:13:36',
#      'firm': 'Evercore ISI Group',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-12-14 12:26:08',
#      'firm': 'B of A Securities',
#      'toGrade': 'Buy',
#      'fromGrade': 'Neutral',
#      'action': 'up'},
#     {'epochGradeDate': '2021-12-13 15:36:22',
#      'firm': 'JP Morgan',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-12-07 14:04:51',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-12-06 12:05:33',
#      'firm': 'Keybanc',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'init'},
#     {'epochGradeDate': '2021-12-02 12:32:09',
#      'firm': 'Wedbush',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-10-29 13:41:38',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-10-29 13:16:45',
#      'firm': 'Barclays',
#      'toGrade': 'Equal-Weight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-10-29 12:56:50',
#      'firm': 'Oppenheimer',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-10-27 15:11:01',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-10-19 14:55:08',
#      'firm': 'DA Davidson',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-09-22 18:07:34',
#      'firm': 'Tigress Financial',
#      'toGrade': 'Strong Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-09-09 15:49:40',
#      'firm': 'Piper Sandler',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-09-01 15:06:05',
#      'firm': 'Wolfe Research',
#      'toGrade': 'Peer Perform',
#      'fromGrade': 'Underperform',
#      'action': 'up'},
#     {'epochGradeDate': '2021-07-28 16:20:34',
#      'firm': 'Loop Capital',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-07-28 16:08:03',
#      'firm': 'Deutsche Bank',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-07-28 16:04:02',
#      'firm': 'Piper Sandler',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-07-28 15:19:21',
#      'firm': 'Canaccord Genuity',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-07-28 14:30:58',
#      'firm': 'Wells Fargo',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-07-28 14:04:58',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-07-28 13:04:39',
#      'firm': 'Barclays',
#      'toGrade': 'Equal-Weight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-07-22 14:24:18',
#      'firm': 'Canaccord Genuity',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-07-20 12:54:27',
#      'firm': 'UBS',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-07-15 13:43:11',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-07-14 16:35:16',
#      'firm': 'JP Morgan',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-07-06 14:27:51',
#      'firm': 'JP Morgan',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-06-24 13:37:32',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-05-28 13:25:16',
#      'firm': 'New Street Research',
#      'toGrade': 'Sell',
#      'fromGrade': 'Neutral',
#      'action': 'down'},
#     {'epochGradeDate': '2021-05-19 12:59:15',
#      'firm': 'Barclays',
#      'toGrade': 'Equal-Weight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-04-29 16:01:59',
#      'firm': 'Barclays',
#      'toGrade': 'Equal-Weight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-04-29 15:40:32',
#      'firm': 'Monness, Crespi, Hardt',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-04-29 15:20:06',
#      'firm': 'Credit Suisse',
#      'toGrade': 'Neutral',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-04-29 15:17:44',
#      'firm': 'Canaccord Genuity',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-04-29 14:36:07',
#      'firm': 'Jefferies',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-04-29 13:44:27',
#      'firm': 'Wedbush',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-04-29 13:44:14',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-04-29 13:16:56',
#      'firm': 'Raymond James',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-04-29 12:21:16',
#      'firm': 'Goldman Sachs',
#      'toGrade': 'Neutral',
#      'fromGrade': 'Sell',
#      'action': 'up'},
#     {'epochGradeDate': '2021-04-21 14:37:53',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-04-16 13:55:19',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-04-06 14:34:09',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-03-31 12:28:11',
#      'firm': 'UBS',
#      'toGrade': 'Buy',
#      'fromGrade': 'Neutral',
#      'action': 'up'},
#     {'epochGradeDate': '2021-03-16 13:55:36',
#      'firm': 'Evercore ISI Group',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-03-10 13:43:57',
#      'firm': 'Wedbush',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-28 20:09:14',
#      'firm': 'DA Davidson',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-28 20:08:11',
#      'firm': 'Deutsche Bank',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-28 20:03:20',
#      'firm': 'Wells Fargo',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-28 19:59:50',
#      'firm': 'Piper Sandler',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-28 19:26:52',
#      'firm': 'Bernstein',
#      'toGrade': 'Market Perform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-28 17:31:45',
#      'firm': 'Credit Suisse',
#      'toGrade': 'Neutral',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-28 17:22:36',
#      'firm': 'Canaccord Genuity',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-28 13:27:30',
#      'firm': 'Raymond James',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-28 12:36:57',
#      'firm': 'Needham',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-28 12:00:12',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-26 16:36:57',
#      'firm': 'Cascend',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-25 17:00:47',
#      'firm': 'Evercore ISI Group',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-25 13:58:40',
#      'firm': 'Raymond James',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-25 12:56:43',
#      'firm': 'Wedbush',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-22 17:23:53',
#      'firm': 'Cowen & Co.',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-21 14:18:45',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-14 18:55:58',
#      'firm': 'Barclays',
#      'toGrade': 'Equal-Weight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-05 16:31:40',
#      'firm': 'Canaccord Genuity',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2021-01-05 14:06:48',
#      'firm': 'Credit Suisse',
#      'toGrade': 'Neutral',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-12-16 18:12:04',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-12-15 17:48:59',
#      'firm': 'Cascend',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-12-09 10:49:54',
#      'firm': 'Wedbush',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-11-30 12:47:25',
#      'firm': 'Loop Capital',
#      'toGrade': 'Buy',
#      'fromGrade': 'Hold',
#      'action': 'up'},
#     {'epochGradeDate': '2020-10-30 12:41:26',
#      'firm': 'Raymond James',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-10-22 17:49:26',
#      'firm': 'Piper Sandler',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-10-14 14:54:46',
#      'firm': 'Credit Suisse',
#      'toGrade': 'Neutral',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-10-14 14:07:26',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-10-12 13:23:23',
#      'firm': 'RBC Capital',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-09-22 13:24:07',
#      'firm': 'Raymond James',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-09-21 18:02:35',
#      'firm': 'Citigroup',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-09-17 16:55:17',
#      'firm': 'Jefferies',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-09-16 12:33:21',
#      'firm': 'Needham',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-09-01 17:51:39',
#      'firm': 'B of A Securities',
#      'toGrade': 'Neutral',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-09-01 15:37:30',
#      'firm': 'JP Morgan',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-09-01 14:50:49',
#      'firm': 'Bank of America',
#      'toGrade': 'Neutral',
#      'fromGrade': '',
#      'action': 'reit'},
#     {'epochGradeDate': '2020-08-31 18:24:32',
#      'firm': 'Argus Research',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-09-24 02:10:26',
#      'firm': 'Wedbush',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-09-14 16:30:59',
#      'firm': 'Cowen & Co.',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-08-26 13:20:42',
#      'firm': 'Wedbush',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-09-14 16:31:16',
#      'firm': 'Morgan Stanley',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-08-10 10:58:04',
#      'firm': 'Wedbush',
#      'toGrade': 'Outperform',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-09-14 16:33:28',
#      'firm': 'Wells Fargo',
#      'toGrade': 'Overweight',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-08-05 17:21:52',
#      'firm': 'B of A Securities',
#      'toGrade': 'Neutral',
#      'fromGrade': 'Buy',
#      'action': 'down'},
#     {'epochGradeDate': '2020-09-14 16:34:04',
#      'firm': 'Cascend',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-09-14 16:33:45',
#      'firm': 'Canaccord Genuity',
#      'toGrade': 'Buy',
#      'fromGrade': '',
#      'action': 'main'},
#     {'epochGradeDate': '2020-09-14 16:36:16',
#      'firm': 'Credit Suisse',
#      'toGrade': 'Neutral',
#      'fromGrade': '',
# ...
#      'shares': 41062,
#      'value': 9914186,
#      'filerUrl': '',
#      'transactionText': 'Sale at price 238.03 - 244.98 per share.',
#      'filerName': 'WILLIAMS JEFFREY E',
#      'filerRelation': 'Chief Operating Officer',
#      'moneyText': '',
#      'startDate': '2020-04-02',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 85678,
#      'filerUrl': '',
#      'transactionText': '',
#      'filerName': 'WILLIAMS JEFFREY E',
#      'filerRelation': 'Chief Operating Officer',
#      'moneyText': '',
#      'startDate': '2020-04-01',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 85678,
#      'filerUrl': '',
#      'transactionText': '',
#      'filerName': 'MAESTRI LUCA',
#      'filerRelation': 'Chief Financial Officer',
#      'moneyText': '',
#      'startDate': '2020-04-01',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 1429,
#      'value': 434573,
#      'filerUrl': '',
#      'transactionText': 'Sale at price 304.11 per share.',
#      'filerName': 'LEVINSON ARTHUR D',
#      'filerRelation': 'Director',
#      'moneyText': '',
#      'startDate': '2020-02-03',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 1429,
#      'filerUrl': '',
#      'transactionText': '',
#      'filerName': 'LEVINSON ARTHUR D',
#      'filerRelation': 'Director',
#      'moneyText': '',
#      'startDate': '2020-01-31',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 1429,
#      'filerUrl': '',
#      'transactionText': '',
#      'filerName': 'SUGAR RONALD D',
#      'filerRelation': 'Director',
#      'moneyText': '',
#      'startDate': '2020-01-31',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 1429,
#      'filerUrl': '',
#      'transactionText': '',
#      'filerName': 'WAGNER SUSAN L',
#      'filerRelation': 'Director',
#      'moneyText': '',
#      'startDate': '2020-01-31',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 1429,
#      'filerUrl': '',
#      'transactionText': '',
#      'filerName': 'JUNG ANDREA',
#      'filerRelation': 'Director',
#      'moneyText': '',
#      'startDate': '2020-01-31',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 1429,
#      'filerUrl': '',
#      'transactionText': '',
#      'filerName': 'BELL JAMES A',
#      'filerRelation': 'Director',
#      'moneyText': '',
#      'startDate': '2020-01-31',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 1429,
#      'filerUrl': '',
#      'transactionText': '',
#      'filerName': 'GORE ALBERT A JR',
#      'filerRelation': 'Director',
#      'moneyText': '',
#      'startDate': '2020-01-31',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 32889,
#      'value': 949081,
#      'filerUrl': '',
#      'transactionText': 'Conversion of Exercise of derivative security at price 28.86 per share.',
#      'filerName': 'GORE ALBERT A JR',
#      'filerRelation': 'Director',
#      'moneyText': '',
#      'startDate': '2020-01-27',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 6880,
#      'value': 0,
#      'filerUrl': '',
#      'transactionText': 'Stock Gift at price 0.00 per share.',
#      'filerName': 'COOK TIMOTHY D',
#      'filerRelation': 'Chief Executive Officer',
#      'moneyText': '',
#      'startDate': '2019-12-27',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 14370,
#      'filerUrl': '',
#      'transactionText': '',
#      'filerName': 'ADAMS KATHERINE L',
#      'filerRelation': 'General Counsel',
#      'moneyText': '',
#      'startDate': '2019-11-13',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 37394,
#      'value': 9639799,
#      'filerUrl': '',
#      'transactionText': 'Sale at price 257.79 per share.',
#      'filerName': 'LEVINSON ARTHUR D',
#      'filerRelation': 'Director',
#      'moneyText': '',
#      'startDate': '2019-11-05',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 37394,
#      'value': 1079082,
#      'filerUrl': '',
#      'transactionText': 'Conversion of Exercise of derivative security at price 28.86 per share.',
#      'filerName': 'LEVINSON ARTHUR D',
#      'filerRelation': 'Director',
#      'moneyText': '',
#      'startDate': '2019-11-05',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 3932,
#      'value': 917178,
#      'filerUrl': '',
#      'transactionText': 'Sale at price 233.26 per share.',
#      'filerName': 'KONDO CHRISTOPHER',
#      'filerRelation': 'Officer',
#      'moneyText': '',
#      'startDate': '2019-10-16',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 12459,
#      'value': 2915904,
#      'filerUrl': '',
#      'transactionText': 'Sale at price 234.04 per share.',
#      'filerName': "O'BRIEN DEIRDRE",
#      'filerRelation': 'Officer',
#      'moneyText': '',
#      'startDate': '2019-10-16',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 6915,
#      'filerUrl': '',
#      'transactionText': '',
#      'filerName': 'KONDO CHRISTOPHER',
#      'filerRelation': 'Officer',
#      'moneyText': '',
#      'startDate': '2019-10-15',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 23967,
#      'filerUrl': '',
#      'transactionText': '',
#      'filerName': "O'BRIEN DEIRDRE",
#      'filerRelation': 'Officer',
#      'moneyText': '',
#      'startDate': '2019-10-15',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 61659,
#      'value': 14081680,
#      'filerUrl': '',
#      'transactionText': 'Sale at price 226.58 - 229.34 per share.',
#      'filerName': 'MAESTRI LUCA',
#      'filerRelation': 'Chief Financial Officer',
#      'moneyText': '',
#      'startDate': '2019-10-07',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 67554,
#      'value': 14797004,
#      'filerUrl': '',
#      'transactionText': 'Sale at price 218.62 - 219.28 per share.',
#      'filerName': 'WILLIAMS JEFFREY E',
#      'filerRelation': 'Chief Operating Officer',
#      'moneyText': '',
#      'startDate': '2019-10-02',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 129308,
#      'filerUrl': '',
#      'transactionText': '',
#      'filerName': 'WILLIAMS JEFFREY E',
#      'filerRelation': 'Chief Operating Officer',
#      'moneyText': '',
#      'startDate': '2019-10-01',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 129308,
#      'filerUrl': '',
#      'transactionText': '',
#      'filerName': 'MAESTRI LUCA',
#      'filerRelation': 'Chief Financial Officer',
#      'moneyText': '',
#      'startDate': '2019-10-01',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 265160,
#      'value': 54667179,
#      'filerUrl': '',
#      'transactionText': 'Sale at price 205.75 - 207.13 per share.',
#      'filerName': 'COOK TIMOTHY D',
#      'filerRelation': 'Chief Executive Officer',
#      'moneyText': '',
#      'startDate': '2019-08-26',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 560000,
#      'filerUrl': '',
#      'transactionText': '',
#      'filerName': 'COOK TIMOTHY D',
#      'filerRelation': 'Chief Executive Officer',
#      'moneyText': '',
#      'startDate': '2019-08-23',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 23700,
#      'value': 0,
#      'filerUrl': '',
#      'transactionText': 'Stock Gift at price 0.00 per share.',
#      'filerName': 'COOK TIMOTHY D',
#      'filerRelation': 'Chief Executive Officer',
#      'moneyText': '',
#      'startDate': '2019-08-22',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 17500,
#      'value': 3529575,
#      'filerUrl': '',
#      'transactionText': 'Sale at price 201.69 per share.',
#      'filerName': 'LEVINSON ARTHUR D',
#      'filerRelation': 'Director',
#      'moneyText': '',
#      'startDate': '2019-08-12',
#      'ownership': 'D'},
#     {'maxAge': 1,
#      'shares': 17500,
#      'value': 416950,
#      'filerUrl': '',
#      'transactionText': 'Conversion of Exercise of derivative security at price 23.83 per share.',
#      'filerName': 'LEVINSON ARTHUR D',
#      'filerRelation': 'Director',
#      'moneyText': '',
#      'startDate': '2019-08-12',
#      'ownership': 'D'}],
#    'maxAge': 1},
#   'sectorTrend': {'maxAge': 1, 'symbol': None, 'estimates': []},
#   'incomeStatementHistoryQuarterly': {'incomeStatementHistory': [{'maxAge': 1,
#      'endDate': '2023-04-01',
#      'totalRevenue': 0,
#      'costOfRevenue': 0,
#      'grossProfit': 0,
#      'researchDevelopment': {},
#      'sellingGeneralAdministrative': {},
#      'nonRecurring': {},
#      'otherOperatingExpenses': {},
#      'totalOperatingExpenses': 0,
#      'operatingIncome': {},
#      'totalOtherIncomeExpenseNet': 0,
#      'ebit': 0,
#      'interestExpense': {},
#      'incomeBeforeTax': {},
#      'incomeTaxExpense': 0,
#      'minorityInterest': {},
#      'netIncomeFromContinuingOps': {},
#      'discontinuedOperations': {},
#      'extraordinaryItems': {},
#      'effectOfAccountingCharges': {},
#      'otherItems': {},
#      'netIncome': 0,
#      'netIncomeApplicableToCommonShares': {}},
#     {'maxAge': 1,
#      'endDate': '2022-12-31',
#      'totalRevenue': 117154000000,
#      'costOfRevenue': 66822000000,
#      'grossProfit': 50332000000,
#      'researchDevelopment': 7709000000,
#      'sellingGeneralAdministrative': 6607000000,
#      'nonRecurring': {},
#      'otherOperatingExpenses': {},
#      'totalOperatingExpenses': 81138000000,
#      'operatingIncome': 36016000000,
#      'totalOtherIncomeExpenseNet': -393000000,
#      'ebit': 36016000000,
#      'interestExpense': -1003000000,
#      'incomeBeforeTax': 35623000000,
#      'incomeTaxExpense': 5625000000,
#      'minorityInterest': {},
#      'netIncomeFromContinuingOps': 29998000000,
#      'discontinuedOperations': {},
#      'extraordinaryItems': {},
#      'effectOfAccountingCharges': {},
#      'otherItems': {},
#      'netIncome': 29998000000,
#      'netIncomeApplicableToCommonShares': 29998000000},
#     {'maxAge': 1,
#      'endDate': '2022-09-24',
#      'totalRevenue': 90146000000,
#      'costOfRevenue': 52051000000,
#      'grossProfit': 38095000000,
#      'researchDevelopment': 6761000000,
#      'sellingGeneralAdministrative': 6440000000,
#      'nonRecurring': {},
#      'otherOperatingExpenses': {},
#      'totalOperatingExpenses': 65252000000,
#      'operatingIncome': 24894000000,
#      'totalOtherIncomeExpenseNet': -237000000,
#      'ebit': 24894000000,
#      'interestExpense': -827000000,
#      'incomeBeforeTax': 24657000000,
#      'incomeTaxExpense': 3936000000,
#      'minorityInterest': {},
#      'netIncomeFromContinuingOps': 20721000000,
#      'discontinuedOperations': {},
#      'extraordinaryItems': {},
#      'effectOfAccountingCharges': {},
#      'otherItems': {},
#      'netIncome': 20721000000,
#      'netIncomeApplicableToCommonShares': 20721000000},
#     {'maxAge': 1,
#      'endDate': '2022-06-25',
#      'totalRevenue': 82959000000,
#      'costOfRevenue': 47074000000,
#      'grossProfit': 35885000000,
#      'researchDevelopment': 6797000000,
#      'sellingGeneralAdministrative': 6012000000,
#      'nonRecurring': {},
#      'otherOperatingExpenses': {},
#      'totalOperatingExpenses': 59883000000,
#      'operatingIncome': 23076000000,
#      'totalOtherIncomeExpenseNet': -10000000,
#      'ebit': 23076000000,
#      'interestExpense': -719000000,
#      'incomeBeforeTax': 23066000000,
#      'incomeTaxExpense': 3624000000,
#      'minorityInterest': {},
#      'netIncomeFromContinuingOps': 19442000000,
#      'discontinuedOperations': {},
#      'extraordinaryItems': {},
#      'effectOfAccountingCharges': {},
#      'otherItems': {},
#      'netIncome': 19442000000,
#      'netIncomeApplicableToCommonShares': 19442000000}],
#    'maxAge': 86400},
#   'cashflowStatementHistoryQuarterly': {'cashflowStatements': [{'maxAge': 1,
#      'endDate': '2023-04-01',
#      'netIncome': 0,
#      'changeToLiabilities': 0},
#     {'maxAge': 1,
#      'endDate': '2022-12-31',
#      'netIncome': 29998000000,
#      'depreciation': 2916000000,
#      'changeToNetincome': 2588000000,
#      'changeToAccountReceivables': 4275000000,
#      'changeToLiabilities': -5944000000,
#      'changeToInventory': -1807000000,
#      'changeToOperatingActivities': 1979000000,
#      'totalCashFromOperatingActivities': 34005000000,
#      'capitalExpenditures': -3787000000,
#      'investments': 2483000000,
#      'otherCashflowsFromInvestingActivities': -141000000,
#      'totalCashflowsFromInvestingActivities': -1445000000,
#      'dividendsPaid': -3768000000,
#      'netBorrowings': -9615000000,
#      'otherCashflowsFromFinancingActivities': -389000000,
#      'totalCashFromFinancingActivities': -35563000000,
#      'changeInCash': -3003000000,
#      'repurchaseOfStock': -21791000000},
#     {'maxAge': 1,
#      'endDate': '2022-09-24',
#      'netIncome': 20721000000,
#      'depreciation': 2865000000,
#      'changeToNetincome': 589000000,
#      'changeToAccountReceivables': -6384000000,
#      'changeToLiabilities': 15774000000,
#      'changeToInventory': 435000000,
#      'changeToOperatingActivities': -9873000000,
#      'totalCashFromOperatingActivities': 24127000000,
#      'capitalExpenditures': -3289000000,
#      'investments': 2806000000,
#      'otherCashflowsFromInvestingActivities': -597000000,
#      'totalCashflowsFromInvestingActivities': -1217000000,
#      'dividendsPaid': -3703000000,
#      'netBorrowings': 1657000000,
#      'otherCashflowsFromFinancingActivities': -12000000,
#      'totalCashFromFinancingActivities': -26794000000,
#      'changeInCash': -3884000000,
#      'repurchaseOfStock': -24736000000},
#     {'maxAge': 1,
#      'endDate': '2022-06-25',
#      'netIncome': 19442000000,
#      'depreciation': 2805000000,
#      'changeToNetincome': 3870000000,
#      'changeToAccountReceivables': -981000000,
#      'changeToLiabilities': -4725000000,
#      'changeToInventory': -16000000,
#      'changeToOperatingActivities': 2497000000,
#      'totalCashFromOperatingActivities': 22892000000,
#      'capitalExpenditures': -2102000000,
#      'investments': 6953000000,
#      'otherCashflowsFromInvestingActivities': -615000000,
#      'totalCashflowsFromInvestingActivities': 4234000000,
#      'dividendsPaid': -3811000000,
#      'netBorrowings': 971000000,
#      'otherCashflowsFromFinancingActivities': -43000000,
#      'totalCashFromFinancingActivities': -27445000000,
#      'changeInCash': -319000000,
#      'repurchaseOfStock': -24562000000}],
#    'maxAge': 86400},
#   'earnings': {'maxAge': 86400,
#    'earningsChart': {'quarterly': [{'date': '2Q2022',
#       'actual': 1.2,
#       'estimate': 1.16},
#      {'date': '3Q2022', 'actual': 1.29, 'estimate': 1.27},
#      {'date': '4Q2022', 'actual': 1.88, 'estimate': 1.94},
#      {'date': '1Q2023', 'actual': 1.52, 'estimate': 1.43}],
#     'currentQuarterEstimate': 1.19,
#     'currentQuarterEstimateDate': '2Q',
#     'currentQuarterEstimateYear': 2023,
#     'earningsDate': ['2023-07-26 22:00:S', '2023-07-31 22:00:S']},
#    'financialsChart': {'yearly': [{'date': 2019,
#       'revenue': 260174000000,
#       'earnings': 55256000000},
#      {'date': 2020, 'revenue': 274515000000, 'earnings': 57411000000},
#      {'date': 2021, 'revenue': 365817000000, 'earnings': 94680000000},
#      {'date': 2022, 'revenue': 394328000000, 'earnings': 99803000000}],
#     'quarterly': [{'date': '2Q2022',
#       'revenue': 82959000000,
#       'earnings': 19442000000},
#      {'date': '3Q2022', 'revenue': 90146000000, 'earnings': 20721000000},
#      {'date': '4Q2022', 'revenue': 117154000000, 'earnings': 29998000000},
#      {'date': '2Q2023', 'revenue': 0, 'earnings': 0}]},
#    'financialCurrency': 'USD'},
#   'pageViews': {'shortTermTrend': 'DOWN',
#    'midTermTrend': 'UP',
#    'longTermTrend': 'UP',
#    'maxAge': 1},
#   'financialData': {'maxAge': 86400,
#    'currentPrice': 170.91,
#    'targetHighPrice': 209.0,
#    'targetLowPrice': 118.0,
#    'targetMeanPrice': 178.88,
#    'targetMedianPrice': 180.0,
#    'recommendationMean': 2.0,
#    'recommendationKey': 'buy',
#    'numberOfAnalystOpinions': 38,
#    'totalCash': 55872000000,
#    'totalCashPerShare': 3.552,
#    'ebitda': 123788001280,
#    'totalDebt': 109614997504,
#    'quickRatio': 0.764,
#    'currentRatio': 0.94,
#    'totalRevenue': 385095008256,
#    'debtToEquity': 176.349,
#    'revenuePerShare': 24.116,
#    'returnOnAssets': 0.20559,
#    'returnOnEquity': 1.4560499,
#    'grossProfits': 170782000000,
#    'freeCashflow': 83796623360,
#    'operatingCashflow': 109583998976,
#    'earningsGrowth': 0.0,
#    'revenueGrowth': -0.025,
#    'grossMargins': 0.43181,
#    'ebitdaMargins': 0.32145,
#    'operatingMargins': 0.29163,
#    'profitMargins': 0.24493,
#    'financialCurrency': 'USD'}}}

# %% [markdown]
# # Dane firm Apple, JP Morgan Chase & Co., Procter & Gamble Company, FedEx Corporation, 3M Company oraz indeksu S&P 500

# %%
last_ten_years = datetime.today() - timedelta(days=365*10)

start_date = last_ten_years
end_date = datetime.today()
start_date_str = start_date.strftime('%Y-%m-%d')
end_date_str = end_date.strftime('%Y-%m-%d')
print('Start date: ', start_date_str, '\nEnd date: ', end_date_str)


data = {}

for stock in stocks:
    df = yf.download(stock, start=start_date_str, end=end_date_str, interval="1d")
    df.reset_index(inplace=True)
    df['Date'] = df['Date'].dt.strftime('%Y-%m-%d') # zmiana formatu daty do formatu YYYY-MM-DD
    df['Return'] = df['Adj Close'].pct_change() # obliczenie stopy zwrotu
    df['Log Return'] = np.log(df['Return'] + 1) # obliczenie zlogarytmizowanej stopy zwrotu
    df.to_csv('data/{}.csv'.format(stock))
    data[stock] = df
# Out:
# Start date:  2013-05-19
# End date:  2023-05-17
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
print('Liczba rekordów: ', len(data['AAPL']))
data['AAPL']
# Out:
# Liczba rekordów:  2516
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2013-05-20   15.425357   15.921429   15.360714   15.818929   13.733949
# 1     2013-05-21   15.648214   15.910000   15.507143   15.702143   13.632556
# 2     2013-05-22   15.858929   16.012501   15.650714   15.762500   13.684957
# 3     2013-05-23   15.569643   15.934286   15.563929   15.790714   13.709449
# 4     2013-05-24   15.744643   15.916429   15.727143   15.898214   13.802786
# ...          ...         ...         ...         ...         ...         ...
# 2511  2023-05-10  173.020004  174.029999  171.899994  173.559998  173.320267
# 2512  2023-05-11  173.850006  174.589996  172.169998  173.750000  173.510010
# 2513  2023-05-12  173.619995  174.059998  171.000000  172.570007  172.570007
# 2514  2023-05-15  173.160004  173.210007  171.470001  172.070007  172.070007
# 2515  2023-05-16  171.990005  173.139999  171.800003  172.070007  172.070007
#
#          Volume    Return  Log Return
# 0     451578400       NaN         NaN
# 1     456022000 -0.007383   -0.007410
# 2     443038400  0.003844    0.003836
# 3     353021200  0.001790    0.001788
# 4     276166800  0.006808    0.006785
# ...         ...       ...         ...
# 2511   53724500  0.010421    0.010367
# 2512   49514700  0.001095    0.001094
# 2513   45497800 -0.005418   -0.005432
# 2514   37266700 -0.002897   -0.002902
# 2515   42071100  0.000000    0.000000
#
# [2516 rows x 9 columns]

# %%
data['AAPL']['Return'].plot(figsize=(8,4), title='AAPL Daily Return')
# Out:
# <AxesSubplot: title={'center': 'AAPL Daily Return'}>

# %% [markdown]
# # Sprawdzenie, czy zyski pochodzą z rozkładu normalnego

# %%
x_list = np.linspace(data['AAPL']['Return'].min(), data['AAPL']['Return'].max(), 100)
y_list = norm.pdf(x_list, data['AAPL']['Return'].mean(), data['AAPL']['Return'].std())
plt.plot(x_list, y_list, color='red')
data['AAPL']['Return'].hist(bins=100, density=True)
plt.show()

# %%
sm.qqplot(data['AAPL']['Return'].dropna(), line='s')

# %% [markdown]
# # Preprocessing danych
# ### Przygotowanie ich w odpowiednim formacie, walidacja i sprawdzenie wartości brakujących

# %%
# dates = pd.date_range(start=data['AAPL']['Date'].min(), end=data['AAPL']['Date'].max(), freq='D')
dates = data['AAPL']['Date']
close_prices = pd.DataFrame(index=dates)

for stock in data:
    df_tmp = pd.DataFrame(data[stock]['Adj Close'].to_numpy(), index=data[stock]['Date'], columns=[stock])
    close_prices = close_prices.join(df_tmp, how='left')

close_prices.to_csv('data/close_prices.csv')
close_prices
# Out:
#                   AAPL         JPM          PG         FDX         MMM  \
# Date
# 2013-05-20   13.733949   39.536797   59.161808   90.576416   82.970818
# 2013-05-21   13.632556   40.088760   58.944874   91.462631   83.186172
# 2013-05-22   13.684957   40.549980   58.959839   89.206718   82.749222
# 2013-05-23   13.709449   40.338287   58.870056   88.714371   82.465416
# 2013-05-24   13.802786   40.572662   61.248814   87.568527   82.360832
# ...                ...         ...         ...         ...         ...
# 2023-05-10  173.320267  136.479996  154.029999  226.330002  100.900002
# 2023-05-11  173.510010  136.050003  154.389999  224.839996  100.779999
# 2023-05-12  172.570007  134.100006  155.960007  222.929993  100.269997
# 2023-05-15  172.070007  135.229996  156.009995  222.419998  100.489998
# 2023-05-16  172.070007  134.320007  155.740005  221.270004   98.010002
#
#                   ^GSPC
# Date
# 2013-05-20  1666.290039
# 2013-05-21  1669.160034
# 2013-05-22  1655.349976
# 2013-05-23  1650.510010
# 2013-05-24  1649.599976
# ...                 ...
# 2023-05-10  4137.640137
# 2023-05-11  4130.620117
# 2023-05-12  4124.080078
# 2023-05-15  4136.279785
# 2023-05-16  4109.899902
#
# [2516 rows x 6 columns]

# %%
close_prices['FDX'].plot(figsize=(10, 5), title='Close Prices')
# Out:
# <AxesSubplot: title={'center': 'Close Prices'}, xlabel='Date'>

# %%
print('Liczba pustych komórek: ', close_prices.isna().sum().sum())
close_prices.isna().sum()
# Out:
# Liczba pustych komórek:  0
# AAPL     0
# JPM      0
# PG       0
# FDX      0
# MMM      0
# ^GSPC    0
# dtype: int64

# %%
close_prices.to_csv('data/close_prices_clean.csv')

# %%
# drop "Date" column
aapl = data['AAPL'].drop(columns=['Date'])

for i, col in enumerate(aapl):
    plt.subplot(2,4,i+1)
    sns.histplot(aapl[col], kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Wizualizacja wszystkich danych

# %% [markdown]
# ## Cały dostępny okres - ostatnie 10 lat

# %%
data_without_sp500 = stocks.copy()
data_without_sp500.remove('^GSPC')

plt.figure(figsize=(10, 5))
for stock in data_without_sp500:
    plt.plot(data[stock]['Date'], data[stock]['Adj Close'], label=stock)
    plt.legend(loc='upper left')

# %% [markdown]
# ## Ostatnie 3 lata

# %%
last_3_years = 365*3
plt.figure(figsize=(10, 5))
for stock in data_without_sp500:
    plt.plot(data[stock]['Date'][-last_3_years:], data[stock]['Adj Close'][-last_3_years:], label=stock)
    plt.legend(loc='upper left')

# %% [markdown]
# ## Ostatnie 12 miesięcy

# %%
plt.figure(figsize=(10, 5))
for stock in data_without_sp500:
    plt.plot(data[stock]['Date'][-365:], data[stock]['Adj Close'][-365:], label=stock)
    plt.legend(loc='upper left')

# %% [markdown]
# # Symulacja kursu akcji

# %%
p0 = data['AAPL'].iloc[-1]['Adj Close']
prices = [p0]
returns = data['AAPL']['Return'].dropna()

for _ in range(1000):
    r = np.random.choice(returns)
    p = prices[-1] * (1 + r)
    prices.append(p)

plt.plot(prices)

# %%
from scipy.stats import t

df, loc, scale = t.fit(data['AAPL']['Return'].dropna())
p0 = data['AAPL'].iloc[-1]['Adj Close']
prices = [p0]

for _ in range(1000):
    r = t.rvs(df, loc, scale)
    p = prices[-1] * (1 + r)
    prices.append(p)

plt.plot(prices)
